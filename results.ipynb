# %%
import pandas as pd

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv("results2025-04-08/all_metrics.csv")

# %%
df = pd.read_csv("results/all_metrics.csv")

# %%
df.sort_values(by=['total_return'], ascending=False).head(10)
# Out:
#     total_return  sharpe_ratio  max_drawdown  win_rate  expectancy  \
# 89    5300271.57         33.93          9.38     96.69    17576.90
# 90      79912.65         20.77         46.53     70.10      412.54
# 41       5929.72         20.23         10.53     87.67       81.35
# 72       1347.39         19.52          7.41     90.91       19.69
# 49        744.14         13.33         10.05     81.13       14.06
# 70        125.23          6.25         29.61     68.18        2.11
# 50         55.16         12.00          6.62    100.00       14.07
# 76         51.33          4.79         17.27     68.00        2.11
# 21         45.37          9.26          4.30     83.33        6.33
# 18         44.22          9.97          8.11    100.00       11.77
#
#                 exposure_time    symbol  strategy_name
# 89  0 days 06:27:02.301369863   VET_BTC  VWAPReversion
# 90  0 days 07:16:02.190669371  VIDT_BTC  VWAPReversion
# 41     0 days 22:30:11.250000  GALA_BTC  VWAPReversion
# ...
